# %%
# Import Python libraries for data manipuation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot

# Import the Python machine learning libraries we need
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import linear_model
import statsmodels.api as sm

# %%
# Load the data set
dataset = pd.read_excel("data.xlsx")

# %%
# Inspect first few rows
dataset.head(12)
# Out:
#      SL  R1  R2  R3  R4  R5  R6  R7  R8  I1  ...  E8  C1  C2  C3  C4  C5  C6  \
# 0    80   5   3   5   4   3   5   2   3   5  ...   5   1   3   3   1   3   2
# 1   162   4   5   5   5   3   5   4   3   3  ...   4   3   4   4   2   4   4
# 2   182   5   2   2   4   1   3   2   2   3  ...   3   2   2   4   3   3   3
# 3   212   4   4   2   4   4   4   5   4   4  ...   3   4   4   5   3   4   5
# 4   282   5   4   5   5   5   5   5   3   4  ...   4   4   5   4   4   5   5
# 5   318   3   3   1   5   4   5   4   4   2  ...   4   1   5   2   1   1   3
# 6   343   4   4   4   4   4   5   4   5   5  ...   4   2   2   2   1   3   5
# 7   356   5   3   1   1   1   1   3   3   5  ...   5   4   3   2   3   5   5
# 8   398   3   1   2   2   1   2   2   1   4  ...   4   3   3   3   3   3   2
# 9   422   2   4   2   5   1   4   3   2   5  ...   2   1   3   2   2   2   4
# 10  424   1   2   1   3   2   3   3   2   2  ...   4   3   2   2   2   2   3
# ...

# %%
# Inspect data shape
dataset.shape
# Out:
# (36775, 50)

# %%
# Inspect descriptive stats
dataset.describe()
# Out:
#                   SL            R1            R2            R3            R4  \
# count   36775.000000  36775.000000  36775.000000  36775.000000  36775.000000
# mean    74444.874045      2.618872      2.135228      1.769055      2.330931
# std     42099.425772      1.315058      1.222695      1.124123      1.340722
# min         4.000000      1.000000      1.000000      1.000000      1.000000
# 25%     37875.500000      1.000000      1.000000      1.000000      1.000000
# 50%     75044.000000      3.000000      2.000000      1.000000      2.000000
# 75%    110998.000000      4.000000      3.000000      2.000000      3.000000
# max    145827.000000      5.000000      5.000000      5.000000      5.000000
#
#                  R5            R6            R7            R8            I1  \
# count  36775.000000  36775.000000  36775.000000  36775.000000  36775.000000
# mean       1.771747      2.257865      2.038967      1.995622      3.465262
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

dataset['major1']=labelencoder.fit_transform(dataset['major'])
dataset
# Out:
#            SL  R1  R2  R3  R4  R5  R6  R7  R8  I1  ...  C1  C2  C3  C4  C5  \
# 0          80   5   3   5   4   3   5   2   3   5  ...   1   3   3   1   3
# 1         162   4   5   5   5   3   5   4   3   3  ...   3   4   4   2   4
# 2         182   5   2   2   4   1   3   2   2   3  ...   2   2   4   3   3
# 3         212   4   4   2   4   4   4   5   4   4  ...   4   4   5   3   4
# 4         282   5   4   5   5   5   5   5   3   4  ...   4   5   4   4   5
# ...       ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..
# 36770   41901   1   3   1   3   1   3   2   2   5  ...   1   3   1   1   5
# 36771   44036   1   2   2   2   2   2   1   2   2  ...   2   2   2   2   3
# 36772   88917   3   3   1   4   3   4   3   3   5  ...   3   4   2   3   2
# 36773  113727   5   4   2   2   2   3   2   3   4  ...   2   3   2   4   5
# 36774  142898   3   3   4   4   1   3   1   3   4  ...   4   3   3   5   4
#
#        C6  C7  C8         major  major1
# ...

# %%
y=dataset["major1"]
X=dataset[["R1","R2","R3","R4","R5","R6","R7","R8","I1","I2","I3","I4","I5","I6","I7","I8","A1","A2","A3","A4","A5","A6","A7","A8","S1","S2","S3","S4","S5","S6","S7","S8","E1","E2","E3","E4","E5","E6","E7","E8","C1","C2","C3","C4","C5","C6","C7","C8"
]]

# %%
# Split into test and training sets
test_size = 0.33
seed = 7
X_train, X_test, y_train, y_test =  train_test_split(X, y, test_size=test_size, random_state=seed)

# %%
X_train
# Out:
#        R1  R2  R3  R4  R5  R6  R7  R8  I1  I2  ...  E7  E8  C1  C2  C3  C4  \
# 35048   1   1   1   2   1   1   2   1   2   2  ...   4   4   3   3   3   3
# 9827    2   1   1   1   1   1   1   1   5   1  ...   1   1   3   1   3   3
# 8683    3   4   3   3   2   4   2   4   5   5  ...   1   2   1   1   1   1
# 31789   1   3   1   1   1   1   1   2   3   1  ...   1   3   3   1   3   3
# 21479   1   1   3   1   2   3   2   2   1   1  ...   4   2   3   1   3   3
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..
# 2583    1   1   3   1   1   1   1   1   3   1  ...   2   1   1   1   1   1
# 34140   2   1   1   1   1   1   1   1   1   1  ...   2   3   3   2   3   2
# 13927   1   3   1   4   1   2   3   3   4   5  ...   1   3   1   2   3   2
# 919     3   5   5   3   3   4   4   2   4   4  ...   5   3   4   4   4   3
# 10742   5   4   3   3   3   4   4   4   3   4  ...   5   3   4   4   4   5
#
#        C5  C6  C7  C8
# 35048   2   3   2   2
# ...

# %%
X_test
# Out:
#        R1  R2  R3  R4  R5  R6  R7  R8  I1  I2  ...  E7  E8  C1  C2  C3  C4  \
# 20360   5   4   4   4   4   2   3   1   5   5  ...   3   3   5   3   4   4
# 14975   1   1   1   1   1   1   1   2   5   4  ...   3   1   1   1   1   2
# 34579   2   1   2   2   1   1   1   1   2   2  ...   4   3   5   3   4   3
# 18895   1   5   1   1   3   2   2   4   1   5  ...   3   5   1   3   1   1
# 6940    3   5   2   5   1   4   4   2   2   3  ...   1   4   5   5   5   3
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..
# 28140   5   5   3   5   3   4   5   5   5   5  ...   3   3   3   5   5   5
# 384     2   3   4   4   4   4   3   4   4   2  ...   1   4   1   4   2   3
# 27753   3   2   1   1   1   1   1   1   3   3  ...   3   4   1   1   1   1
# 1826    4   4   4   4   3   3   4   2   4   4  ...   2   4   4   4   4   3
# 9781    4   4   3   5   4   4   5   4   3   1  ...   3   4   2   4   3   3
#
#        C5  C6  C7  C8
# 20360   4   3   4   4
# ...

# %%
y_train
# Out:
# 35048    2
# 9827     3
# 8683     3
# 31789    5
# 21479    3
#         ..
# 2583     4
# 34140    2
# 13927    3
# 919      4
# 10742    3
# Name: major1, Length: 24639, dtype: int32

# %%
y_test
# Out:
# 20360    3
# 14975    3
# 34579    2
# 18895    3
# 6940     3
#         ..
# 28140    5
# 384      4
# 27753    5
# 1826     4
# 9781     3
# Name: major1, Length: 12136, dtype: int32

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  2.8944807018864744
# Coefficients:
#  [-0.0081436  -0.03411178  0.07341345  0.04084694  0.03112609  0.00650767
#   0.0293958   0.02569972 -0.0135527  -0.01034246  0.00022732  0.03509846
#   0.01015995 -0.00751629 -0.00589472  0.01161972 -0.02090737 -0.00154047
#  -0.0720885  -0.02053929 -0.00173969 -0.03703538 -0.0235149  -0.03876053
#   0.0458441   0.01043616  0.01301526  0.01043508  0.01393473  0.06425687
#   0.03986366  0.01257193 -0.02761675  0.00340153 -0.00262979 -0.00304362
#   0.02249674 -0.00984303  0.02656999  0.00321818 -0.04371095  0.00212895
#  -0.00137697  0.01503636 -0.01106865  0.0159606  -0.10094472 -0.0335381 ]

# %%
new_R1=4
new_R2=3
new_R3=1
new_R4=2
new_R5=1
new_R6=2
new_R7=1
new_R8=2
new_I1=5
new_I2=4
new_I3=4
new_I4=4
new_I5=3
new_I6=4
new_I7=3
new_I8=2
new_A1=5
new_A2=5
new_A3=5
new_A4=5
new_A5=3
new_A6=5
new_A7=2
new_A8=4
new_S1=4
new_S2=3
new_S3=2
new_S4=5
new_S5=3
new_S6=4
new_S7=4
new_S8=2
new_E1=2
new_E2=3
new_E3=4
new_E4=2
new_E5=4
new_E6=3
new_E7=2
new_E8=2
new_C1=3
new_C2=2
new_C3=2
new_C4=2
new_C5=2
new_C6=2
new_C7=2
new_C8=1
print ('Predicted Career Path: \n', regr.predict([[new_R1,new_R2,new_R3,new_R4,new_R5,new_R6,new_R7,new_R8,new_I1,new_I2,new_I3,new_I4,new_I5,new_I6,new_I7,new_I8,new_A1,new_A2,new_A3,new_A4,new_A5,new_A6,new_A7,new_A8,new_S1,new_S2,new_S3,new_S4,new_S5,new_S6,new_S7,new_S8,new_E1,new_E2,new_E3,new_E4,new_E5,new_E6,new_E7,new_E8,new_C1,new_C2,new_C3,new_C4,new_C5,new_C6,new_C7,new_C8]]))
# Out:
# Predicted Career Path:
#  [2.61942865]

# %%
# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 major1   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     40.43
# Date:                Fri, 31 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:46:48   Log-Likelihood:                -61255.
# No. Observations:               36775   AIC:                         1.226e+05
# Df Residuals:                   36726   BIC:                         1.230e+05
# Df Model:                          48
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8945      0.038     75.402      0.000       2.819       2.970
# ...
